# %% [markdown]
# ## data assessing

# %% [markdown]
# ### date
#    #### row number (3)
#
# ### startup
#   ### row level
#   #### row number (67,708,709,1160,1352,1390,1394,1510,1876,2500,2779,2787,2939)
#
# ### vertical
#  ### column level
#      ecommerce , E-commerce,Ecommerce
#
#    row number (2171,2216,2234,2360,2381,2390,2405,2415,2484,2504,2632,2676,2811,2809)
#
# ### missing values (2858)
#
#
# ### subvertical
#  ### row level
#  #### row number( 434,680,748,768,848,899,1211,1240,1314,1342,1409,1411,1430,1458,1539,1549,1609,1682,1765,177,1799,1842,1847,2053,2084)
#  ### missing values( 2106-)
#  some subverticals are too big
#
#
#
# ### city
#    #### column level
#
#     Gurgaon somewhere gurugram , Delhi somewhere nw delhi , bangalore , bangaluru (consistensy issue)
#
# ### missing values
#    ### row number ( 1596,1761,1807)
#
#
# ### investor
#  #### row number (108,112,123,137,148,153,156,178,254,400,460,478,656,787,838,870,874,964,1069,1095,1162,1182,1228,1267,1447,1506,1523,1748,1820,1887,1901,1902,1945,1946,1951,1982,2012,2033,2048,2058,2066,2124,2149,2223,2259,2279,2308,2320,2630,2638,2646,2673,2678,2687,2728,2761,2806,2845,2876,2890,2917,2963)
#
#
# ### round (fixed)
#
# ### amount

# %% [markdown]
# think subvertical has been shifted to vertical

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Nadeem Anwar\Desktop\projects\startup dashboard\startup_cleaned.csv")

# %%
# since rows had been shifted to vertical 
# fix that 

# create mask for rows where subvertical is missing
mask = data["subvertical"].isna()

# shift the values of vertical -> subvertical for those rows
data.loc[mask, ["vertical", "subvertical"]] = (
    data.loc[mask, ["vertical", "subvertical"]]
    .shift(axis=1)
)


# check result

# %%
data.iloc[2105]

# %%
#fixing date column
data[data['date'].isna()]
data["date"]=data["date"].fillna(method='ffill')

# %%
data[data["date"].isna()]
# now date column has no missing value

# %%
data[data["vertical"].isna()].tail(1)["startup"].to_list()

# %% [markdown]
# found first 30 none verticals then found their vertical according to the startup , did this process for 925 none values then filles none in verticals by series "vertical_ref_serirs"

# %%
sixtee_to_nitee=[]
for i in range (1,len(data[data["vertical"].isna()].head(926)["startup"].to_list())):
    if i>899:
        sixtee_to_nitee.append(data[data["vertical"].isna()].head(926)["startup"].to_list()[i])
print(sixtee_to_nitee)

# %%
data[data["vertical"].isna()].index.to_list()

# %%
vertical_list=[
 'EdTech',
 'Fashion',
 'FoodTech',
 'Logistics',
 'SaaS',
 'Fashion',
 'HealthTech',
 'Travel',
 'Fashion',
 'Fashion',
 'FoodTech',
 'Mobility',
 'EdTech',
 'Fitness',
 'Marketing',
 'Mobility',
 'Wedding',
 'Ecommerce',
 'Energy',
 'Ecommerce',
 'FoodTech',
 'EdTech',
 'Wearables',
 'Cloud',
 'SaaS',
 'B2B',
 'FoodTech',
 'EdTech',
 'Delivery',
 'ITServices',
 'FinTech',
 'Ecommerce',
 'Logistics',
 'Interiors',
 'AI',
 'Energy',
 'Logistics',
 'Travel',
 'FinTech',
 'FinTech',
 'EdTech',
 'Community',
 'Analytics',
 'Services',
 'GovTech',
 'Retail',
 'Wedding',
 'AI',
 'Interiors',
 'Aviation',
 'Mobility',
 'Wearables',
 'Events',
 'Media',
 'AI',
 'Services',
 'Ecommerce',
 'HealthTech',
 'Fashion',
 'Logistics','EdTech',
 'FoodTech',
 'EV',
 'FinTech',
 'Media',
 'Logistics',
 'Logistics',
 'FoodTech',
 'Sports',
 'Mobility',
 'Ecommerce',
 'AdTech',
 'Ecommerce',
 'Travel',
 'AI',
 'HealthTech',
 'Fitness',
 'Ecommerce',
 'Gaming',
 'Ecommerce',
 'Ecommerce',
 'Fashion',
 'Collaboration',
 'Media',
 'Ecommerce',
 'Automotive',
 'FoodTech',
 'FinTech',
 'AI',
 'FoodTech','Mobility',
 'Local',
 'Ecommerce',
 'AdTech',
 'SaaS',
 'FoodTech',
 'FinTech',
 'Travel',
 'Energy',
 'AI',
 'Music',
 'MentalHealth',
 'Services',
 'Travel',
 'Messaging',
 'Reputation',
 'Grocery',
 'Media',
 'Automotive',
 'Events',
 'HealthTech',
 'Hospitality',
 'Marketing',
 'EdTech',
 'Beauty',
 'Fashion',
 'Mobility',
 'EdTech',
 'FoodTech',
 'FoodTech',
 'FoodTech',
 'Networking',
 'FinTech',
 'Mobility',
 'Gaming',
 'Ecommerce',
 'Cashback',
 'AI',
 'Services',
 'Rewards',
 'Ecommerce',
 'AI',
 'Fashion',
 'Ecommerce',
 'Cloud',
 'EdTech',
 'Mobility',
 'Payments',
 'Media',
 'Logistics',
 'Logistics',
 'Freelance',
 'Mobility',
 'Services',
 'Wearables',
 'Ecommerce',
 'Fashion',
 'Sales',
 'Fashion',
 'HealthTech',
 'Social',
 'Hospitality',
 'HealthTech',
 'Ecommerce',
 'Collaboration',
 'Mobility',
 'HealthTech',
 'Fashion',
 'Services',
 'Ecommerce',
 'Analytics',
 'FinTech',
 'B2B',
 'Publishing',
 'AI',
 'Fitness',
 'Grocery',
 'HealthTech',
 'FinTech',
 'Beauty',
 'Mobility',
 'EdTech',
 'EdTech',
 'Talent',
 'Mobility',
 'Mobility',
 'FMCG',
 'Marketing',
 'Logistics',
 'Gaming',
 'Services',
 'FinTech',
 'B2B',
 'Services',
 'Entertainment',
 'Travel',
 'FinTech',
 'Marketing',
 'FinTech',
 'Beauty',
 'Jewelry',
 'FinTech',
 'Ecommerce',
 'HealthTech',
 'Jobs',
 'Sports',
 'EdTech',
 'FoodTech',
 'HealthTech',
 'EdTech',
 'Grocery',
 'Logistics',
 'AI',
 'Fashion',
 'FoodTech',
 'AI',
 'Analytics',
 'Housing',
 'FinTech',
 'SaaS',
 'HealthTech',
 'FinTech',
 'FoodTech',
 'Travel',
 'Lifestyle',
 'Ecommerce',
 'Mobility',
 'FinTech',
 'B2B',
 'SaaS',
 'Travel',
 'Telecom',
 'Gaming',
 'Local',
 'Gifting',
 'Music',
 'FoodTech',
 'Fitness',
 'Rewards',
 'FoodTech',
 'Logistics',
 'RealEstate',
 'AI',
 'Investment',
 'FinTech',
 'Travel',
 'Retail',
 'Analytics',
 'HealthTech',
 'FoodTech','FoodTech',
 'RealEstate',
 'Beverage',
 'FoodTech',
 'Housing',
 'FinTech',
 'HealthTech',
 'Travel',
 'Grocery',
 'Travel',
 'Logistics',
 'EdTech',
 'Freelance',
 'Pharmacy',
 'FinTech',
 'HR',
 'Kids',
 'HealthTech',
 'Logistics',
 'SaaS',
 'FinTech',
 'EdTech',
 'Delivery',
 'FinTech',
 'B2B',
 'Mobility',
 'AI',
 'Logistics',
 'Logistics',
 'FoodTech',
 'EdTech',
 'Social',
 'Marketing',
 'Mobility',
 'IoT',
 'FinTech',
 'Fashion',
 'Luxury',
 'FoodTech',
 'Fashion',
 'SaaS',
 'Jobs',
 'HealthTech',
 'FinTech',
 'AI',
 'Social',
 'Logistics',
 'Hospitality',
 'Media',
 'Logistics',
 'FoodTech',
 'Dairy',
 'EdTech',
 'EdTech',
 'EdTech',
 'EdTech',
 'B2B',
 'Nonprofit',
 'Fitness',
 'Fashion',
  'Fashion',
 'Home',
 'Automotive',
 'Travel',
 'Design',
 'Logistics',
 'HealthTech',
 'Mobility',
 'InsurTech',
 'Marketing',
 'Telecom',
 'FoodTech',
 'Hospitality',
 'Beauty',
 'FoodTech',
 'Wedding',
 'B2B',
 'Logistics',
 'Services',
 'Fashion',
 'FoodTech',
 'Collaboration',
 'Health',
 'Manufacturing',
 'Marketplace',
 'Grocery',
 'HealthTech',
 'Analytics',
 'FoodTech',
 'Ecommerce',
 'FinTech',
 'AgriTech',
 'FinTech',
 'Gaming',
 'Grooming',
 'ITServices',
 'FoodTech',
 'Logistics',
 'Security',
 'HealthTech',
 'Trading',
 'AdTech',
 'Publishing',
 'FoodTech',
 'SaaS',
 'EdTech',
 'Energy',
 'FoodTech',
 'Travel',
 'Delivery',
 'Mobility',
 'FinTech',
 'AdTech',
 'Grocery',
 'Aviation',
 'HR',
 'Ecommerce',
 'FinTech',
 'Data',
 'Hospitality',
 'Marketing',
 'Media',
 'Ecommerce',
 'FoodTech',
 'EdTech',
 'Logistics',
 'Beauty',
 'Mobility',
 'Hospitality',
 'Logistics',
 'Marketing',
 'Logistics',
 'B2B',
 'Logistics',
 'Hospitality',
 'Services',
 'Travel',
 'FoodTech',
 'RealEstate',
 'Fashion',
 'Security',
 'HealthTech',
 'Marketing',
 'Travel',
 'Crowdfunding',
 'Payments',
 'Ecommerce',
 'FoodTech',
 'Loyalty',
 'Education',
 'Storage',
 'Grocery',
 'Mobility',
 'Local',
 'Analytics',
 'Gaming',
 'Deals',
 'Printing',
 'Payments',
 'Robotics',
 'Interiors',
 'FoodTech',
 'AgriTech',
 'ITServices',
 'ITServices',
 'Services',
 'Grocery',
 'Community',
 'FinTech',
 'SaaS',
 'Finance',
 'Marketing',
 'AgriTech',
 'ITServices',
 'Logistics',
 'Beauty',
 'EdTech',
 'Media',
 'Sustainability',
 'AI',
 'Services',
 'B2B',
 'Logistics',
 'Media',
 'Social',
 'Analytics',
 'AI',
 'Messaging',
 'Security',
 'Social',
 'Fashion',
 'Services',
 'Fashion',
 'Furniture',
 'Healthcare',
 'RealEstate',
 'Ecommerce',
 'HR',
 'FoodTech',
 'Events',
 'SaaS',
 'Transport',
 'Social',
 'FoodTech',
 'Marketing',
 'Ecommerce',
 'Services',
 'Beauty',
 'Energy',
 'FoodTech',
 'Security',
 'EdTech',
 'Hospitality',
 'FoodTech',
 'Beauty',
 'FoodTech',
 'Media',
 'FoodTech',
 'AI',
 'Analytics',
 'Logistics',
 'ITServices',
 'Analytics',
 'Services',
 'EdTech',
 'Mobility',
 'ITServices',
 'FinTech',
 'Ecommerce',
 'Energy',
 'EdTech',
 'Fitness',
 'FoodTech',
 'Fashion',
 'Furniture',
 'Fashion',
 'Travel',
 'Beverage',
 'Delivery',
 'Hospitality',
 'RealEstate',
 'FoodTech',
 'FinTech',
 'Media',
 'Music',
 'Analytics',
 'Analytics',
 'Coupons',
 'EV',
 'FoodTech',
 'Collectibles',
 'FinTech',
 'HealthTech',
 'Mobility',
 'Ecommerce',
 'Storage',
 'EdTech',
 'Mobility',
 'Logistics',
 'Hospitality',
 'Analytics',
 'Social',
 'Logistics',
 'Crowdfunding',
 'FinTech',
 'Ecommerce',
 'Hospitality',
 'Payments',
 'Analytics',
 'Organic',
 'Analytics',
 'Culinary',
 'Housing',
 'Payments',
 'Ecommerce',
 'Social',
 'HealthTech',
 'Travel',
 'Fitness',
 'Ecommerce',
 'Aviation',
 'Social',
 'Local',
 'Automotive',
 'Beauty',
 'Delivery',
 'Logistics',
 'Events',
 'Furniture',
 'Ecommerce',
 'Analytics',
 'HealthTech',
 'Services',
 'HealthTech',
 'Ecommerce',
 'Water',
 'Fashion',
 'Consulting',
 'Automotive',
 'Gaming',
 'FoodTech',
 'Social',
 'Automotive',
 'Lifestyle',
 'Travel',
 'Media',
 'Food',
 'Beauty',
 'Food',
 'Automotive',
 'EdTech',
 'FoodTech',
 'Automotive',
 'Beauty',
 'RealEstate',
 'Interiors',
 'Analytics',
 'HealthTech',
 'HealthTech',
 'IoT',
 'RealEstate',
 'Mobility',
 'Security',
 'Media',
 'Gaming',
 'Ecommerce',
 'Fashion',
 'Logistics',
 'Video',
 'Ecommerce',
 'Ecommerce',
 'Energy',
 'HealthTech',
 'Mobility',
 'Ecommerce',
 'Energy',
 'Fashion',
 'FoodTech',
 'Payments',
 'Printing',
 'Sustainability',
 'Travel',
 'Fashion',
 'Marketing',
 'FinTech',
 'Pharma',
 'Interiors',
 'EdTech',
 'Logistics',
 'FoodTech',
 'Recycling',
 'Coupons',
 'Parenting',
 'Ecommerce',
 'Dental',
 'Mobility',
 '3DPrinting',
 'Consulting',
 'Fitness',
 'EdTech',
 'Services',
 'FinTech',
 'AI',
 'Analytics',
 'FoodTech',
 'Travel',
 'Travel',
 'EdTech',
 'Video',
 'Infrastructure',
 'Services',
 'Hospitality',
 'EdTech',
 'HealthTech',
 'EdTech',
 'Beauty',
 'EdTech',
 'Data',
 'Logistics',
 'AI',
 'FinTech',
 'Mobility',
 'FinTech',
 'Services',
 'Services',
 'Beauty',
 'Marketing',
 'Services',
 'Lingerie',
 'Travel',
 'Ecommerce',
 'Social',
 'Finance',
 'FoodTech',
 'Media',
 'SaaS',
 'Art',
 'FoodTech',
 'EdTech',
 'Careers',
 'RealEstate',
 'FinTech',
 'CRM',
 'Logistics',
 'FoodTech',
 'AI',
 'FoodTech',
 'EdTech',
 'EdTech',
 'Ecommerce',
 'EdTech',
 'Security',
 'Survey',
 'Fitness',
 'Fashion',
 'Social',
 'Fitness',
 'EdTech',
 'Industrial',
 'HealthTech',
 'Coworking',
 'Ecommerce',
 'Social',
 'Events',
 'Media',
 'Social',
 'FoodTech',
 'Consumer',
 'Social',
 'EdTech',
 'Travel',
 'Rewards',
 'Logistics',
 'Local',
 'Energy',
 'Marketing',
 'Automotive',
 'FoodTech',
 'FinTech',
 'Parenting',
 'Payments',
 'EdTech',
 'Payments',
 'Design',
 'Developer',
 'Hospitality',
 'Logistics',
 'Jobs',
 'Mobility',
 'Fitness',
 'EV',
 'FoodTech',
 'Ecommerce',
 'Security',
 'Social',
 'Deals',
 'Ecommerce',
 'Media',
 'Logistics',
 'Babycare',
 'FinTech',
 'Mobility',
 'Ecommerce',
 'Kitchen',
 'Confectionery',
 'Furniture',
 'HR',
 'SaaS',
 'Food',
 'FoodTech',
 'Grocery',
 'Nonprofit',
 'Logistics',
 'Analytics',
 'Interiors',
 'Services',
 'Grocery',
 'Grocery',
 'InsurTech',
 'Services',
 'Services',
 'ITServices',
 'Services',
 'Beauty',
 'Recycling',
 'HealthTech',
 'SaaS',
 'Local',
 'Local',
 'Ecommerce',
 'EdTech',
 'EdTech',
 'Ecommerce',
 'Travel',
 'FinTech',
 'Mobility',
 'FoodTech',
 'Security',
 'InsurTech',
 'FoodTech',
 'Mobility',
 'EdTech',
 'Education',
 'Jobs',
 'Furniture',
 'Robotics',
 'Ecommerce',
 'Sustainability',
 'Legal',
 'Analytics',
 'FoodTech',
 'Trading',
 'Analytics',
 'Travel',
 'Dating',
 'Social',
 'AdTech',
 'Security',
 'Deals',
 'Furniture',
 'HealthTech',
 'Social',
 'FoodTech',
 'Grocery',
 'Analytics',
 'Fitness',
 'SaaS',
 'Deals',
 'Localization',
 'Gaming',
 'FoodTech',
 'FinTech',
 'HealthTech',
 'Mobility',
 'HealthTech',
 'AI',
 'Travel',
 'Media',
 'Housing',
 'Media',
 'Mobility',
 'Sports',
 'ITServices',
 'Travel',
 'Logistics',
 'Travel',
 'Media',
 'Hardware',
 'RealEstate',
 'Storage',
 'Automotive',
 'Gaming',
 'FinTech',
 'Payments',
 'Furniture',
 'Gaming',
 'Beverage',
 'FinTech',
 'Trading',
 'Jobs',
 'Hospitality',
 'Social',
 'Hardware',
 'HR',
 'Energy',
 'Energy',
 'Gaming',
 'Fashion',
 'Aerospace',
 'FinTech',
 'Payments',
 'Travel',
 'Networking',
 'Insurance',
 'Fashion',
 'Travel',
 'Food',
 'Deals',
 'EdTech',
 'Wearables',
 'FinTech',
 'FoodTech',
 'SaaS',
 'Babycare',
 'FoodTech',
 'Grocery',
 'Analytics',
 'Ecommerce',
 'Media',
 'FinTech',
 'Dating',
 'FinTech',
 'News',
 'Jobs',
 'Automotive',
 'FoodTech',
 'Automotive',
 'Retail',
 'FinTech',
 'IoT',
 'Events',
 'Local',
 'Hospitality',
 'HealthTech',
 'Compliance',
 'Fashion',
 'Payments',
 'News',
 'Travel',
 'ITServices',
 'Social',
 'Design',
 'Video',
 'Design',
 'SaaS',
 'Interiors',
 'Travel',
 'Travel',
 'RealEstate',
 'Ecommerce',
 'Gaming',
 'ITServices',
 'Tax',
 'Grocery',
 'FoodTech',
 'B2B',
 'Grocery',
 'FoodTech',
 'FinTech',
 'Grocery',
 'Ecommerce',
 'Fashion',
 'Local',
 'Video',
 'Fitness',
 'Local',
 'Beauty',
 'FinTech',
 'FinTech',
 'Social',
 'FinTech',
 'Parenting',
 'Fashion',
 'Wearables',
 'RealEstate',
 'Marketing',
 'Fashion',
 'FoodTech',
 'Wellness',
 'Ecommerce',
 'Marketing',
 'Travel',
 'Crowdfunding',
 'HealthTech',
 'Ecommerce',
 'HR',
 'Marketing',
 'Health',
 'Travel',
 'Sports',
 'EdTech',
 'SaaS',
 'Media',
 'Babycare',
 'Media',
 'Health',
 'EdTech',
 'Ecommerce',
 'Social',
 'Social',
 'Analytics',
 'FoodTech',
 'EdTech',
 'Analytics',
 'Jewelry',
 'Jobs',
 'EdTech',
 'Entertainment',
 'Automotive',
 'Housing',
 'Printing',
 'Material',
 'AI',
 'Hospitality',
 'Coupons'




]

vertical_ref_series=pd.Series(vertical_list)
len(vertical_list)

# %%
vertical_ref_series.index=[2104,
 2105,
 2106,
 2107,
 2108,
 2109,
 2110,
 2111,
 2112,
 2113,
 2114,
 2115,
 2116,
 2117,
 2118,
 2119,
 2120,
 2121,
 2122,
 2123,
 2124,
 2125,
 2126,
 2127,
 2128,
 2129,
 2130,
 2131,
 2132,
 2133,
 2134,
 2135,
 2136,
 2137,
 2138,
 2139,
 2140,
 2141,
 2142,
 2143,
 2144,
 2145,
 2146,
 2147,
 2148,
 2149,
 2150,
 2151,
 2152,
 2153,
 2154,
 2155,
 2156,
 2157,
 2158,
 2159,
 2160,
 2161,
 2162,
 2163,
 2164,
 2165,
 2166,
 2167,
 2168,
 2169,
 2170,
 2171,
 2172,
 2173,
 2174,
 2175,
 2176,
 2177,
 2178,
 2179,
 2180,
 2181,
 2182,
 2183,
 2184,
 2185,
 2186,
 2187,
 2188,
 2189,
 2190,
 2191,
 2192,
 2193,
 2194,
 2195,
 2196,
 2197,
 2198,
 2199,
 2200,
 2201,
 2202,
 2203,
 2204,
 2205,
 2206,
 2207,
 2208,
 2209,
 2210,
 2211,
 2212,
 2213,
 2214,
 2215,
 2216,
 2217,
 2218,
 2219,
 2220,
 2221,
 2222,
 2223,
 2224,
 2225,
 2226,
 2227,
 2228,
 2229,
 2230,
 2231,
 2232,
 2233,
 2234,
 2235,
 2236,
 2237,
 2238,
 2239,
 2240,
 2241,
 2242,
 2243,
 2244,
 2245,
 2246,
 2247,
 2248,
 2249,
 2250,
 2251,
 2252,
 2253,
 2254,
 2255,
 2256,
 2257,
 2258,
 2259,
 2260,
 2261,
 2262,
 2263,
 2264,
 2265,
 2266,
 2267,
 2268,
 2269,
 2270,
 2271,
 2272,
 2273,
 2274,
 2275,
 2276,
 2277,
 2278,
 2279,
 2280,
 2281,
 2282,
 2283,
 2284,
 2285,
 2286,
 2287,
 2288,
 2289,
 2290,
 2291,
 2292,
 2293,
 2294,
 2295,
 2296,
 2297,
 2298,
 2299,
 2300,
 2301,
 2302,
 2303,
 2304,
 2305,
 2306,
 2307,
 2308,
 2309,
 2310,
 2311,
 2312,
 2313,
 2314,
 2315,
 2316,
 2317,
 2318,
 2319,
 2320,
 2321,
 2322,
 2323,
 2324,
 2325,
 2326,
 2327,
 2328,
 2329,
 2330,
 2331,
 2332,
 2333,
 2334,
 2335,
 2336,
 2337,
 2338,
 2339,
 2340,
 2341,
 2342,
 2343,
 2344,
 2345,
 2346,
 2347,
 2348,
 2349,
 2350,
 2351,
 2352,
 2353,
 2354,
 2355,
 2356,
 2357,
 2358,
 2359,
 2360,
 2361,
 2362,
 2363,
 2364,
 2365,
 2366,
 2367,
 2368,
 2369,
 2370,
 2371,
 2372,
 2373,
 2374,
 2375,
 2376,
 2377,
 2378,
 2379,
 2380,
 2381,
 2382,
 2383,
 2384,
 2385,
 2386,
 2387,
 2388,
 2389,
 2390,
 2391,
 2392,
 2393,
 2394,
 2395,
 2396,
 2397,
 2398,
 2399,
 2400,
 2401,
 2402,
 2403,
 2404,
 2405,
 2406,
 2407,
 2408,
 2409,
 2410,
 2411,
 2412,
 2413,
 2414,
 2415,
 2416,
 2417,
 2418,
 2419,
 2420,
 2421,
 2422,
 2423,
 2424,
 2425,
 2426,
 2427,
 2428,
 2429,
 2430,
 2431,
 2432,
 2433,
 2434,
 2435,
 2436,
 2437,
 2438,
 2439,
 2440,
 2441,
 2442,
 2443,
 2444,
 2445,
 2446,
 2447,
 2448,
 2449,
 2450,
 2451,
 2452,
 2453,
 2454,
 2455,
 2456,
 2457,
 2458,
 2459,
 2460,
 2461,
 2462,
 2463,
 2464,
 2465,
 2466,
 2467,
 2468,
 2469,
 2470,
 2471,
 2472,
 2473,
 2474,
 2475,
 2476,
 2477,
 2478,
 2479,
 2480,
 2481,
 2482,
 2483,
 2484,
 2485,
 2486,
 2487,
 2488,
 2489,
 2490,
 2491,
 2492,
 2493,
 2494,
 2495,
 2496,
 2497,
 2498,
 2499,
 2500,
 2501,
 2502,
 2503,
 2504,
 2505,
 2506,
 2507,
 2508,
 2509,
 2510,
 2511,
 2512,
 2513,
 2514,
 2515,
 2516,
 2517,
 2518,
 2519,
 2520,
 2521,
 2522,
 2523,
 2524,
 2525,
 2526,
 2527,
 2528,
 2529,
 2530,
 2531,
 2532,
 2533,
 2534,
 2535,
 2536,
 2537,
 2538,
 2539,
 2540,
 2541,
 2542,
 2543,
 2544,
 2545,
 2546,
 2547,
 2548,
 2549,
 2550,
 2551,
 2552,
 2553,
 2554,
 2555,
 2556,
 2557,
 2558,
 2559,
 2560,
 2561,
 2562,
 2563,
 2564,
 2565,
 2566,
 2567,
 2568,
 2569,
 2570,
 2571,
 2572,
 2573,
 2574,
 2575,
 2576,
 2577,
 2578,
 2579,
 2580,
 2581,
 2582,
 2583,
 2584,
 2585,
 2586,
 2587,
 2588,
 2589,
 2590,
 2591,
 2592,
 2593,
 2594,
 2595,
 2596,
 2597,
 2598,
 2599,
 2600,
 2601,
 2602,
 2603,
 2604,
 2605,
 2606,
 2607,
 2608,
 2609,
 2610,
 2611,
 2612,
 2613,
 2614,
 2615,
 2616,
 2617,
 2618,
 2619,
 2620,
 2621,
 2622,
 2623,
 2624,
 2625,
 2626,
 2627,
 2628,
 2629,
 2630,
 2631,
 2632,
 2633,
 2634,
 2635,
 2636,
 2637,
 2638,
 2639,
 2640,
 2641,
 2642,
 2643,
 2644,
 2645,
 2646,
 2647,
 2648,
 2649,
 2650,
 2651,
 2652,
 2653,
 2654,
 2655,
 2656,
 2657,
 2658,
 2659,
 2660,
 2661,
 2662,
 2663,
 2664,
 2665,
 2666,
 2667,
 2668,
 2669,
 2670,
 2671,
 2672,
 2673,
 2674,
 2675,
 2676,
 2677,
 2678,
 2679,
 2680,
 2681,
 2682,
 2683,
 2684,
 2685,
 2686,
 2687,
 2688,
 2689,
 2690,
 2691,
 2692,
 2693,
 2694,
 2695,
 2696,
 2697,
 2698,
 2699,
 2700,
 2701,
 2702,
 2703,
 2704,
 2705,
 2706,
 2707,
 2708,
 2709,
 2710,
 2711,
 2712,
 2713,
 2714,
 2715,
 2716,
 2717,
 2718,
 2719,
 2720,
 2721,
 2722,
 2723,
 2724,
 2725,
 2726,
 2727,
 2728,
 2729,
 2730,
 2731,
 2732,
 2733,
 2734,
 2735,
 2736,
 2737,
 2738,
 2739,
 2740,
 2741,
 2742,
 2743,
 2744,
 2745,
 2746,
 2747,
 2748,
 2749,
 2750,
 2751,
 2752,
 2753,
 2754,
 2755,
 2756,
 2757,
 2758,
 2759,
 2760,
 2761,
 2762,
 2763,
 2764,
 2765,
 2766,
 2767,
 2768,
 2769,
 2770,
 2771,
 2772,
 2773,
 2774,
 2775,
 2776,
 2777,
 2778,
 2779,
 2780,
 2781,
 2782,
 2783,
 2784,
 2785,
 2786,
 2787,
 2788,
 2789,
 2790,
 2791,
 2792,
 2793,
 2794,
 2795,
 2796,
 2797,
 2798,
 2799,
 2800,
 2801,
 2802,
 2803,
 2804,
 2805,
 2806,
 2807,
 2808,
 2809,
 2810,
 2811,
 2812,
 2813,
 2814,
 2815,
 2816,
 2817,
 2818,
 2819,
 2820,
 2821,
 2822,
 2823,
 2824,
 2825,
 2826,
 2827,
 2828,
 2829,
 2830,
 2831,
 2832,
 2833,
 2834,
 2835,
 2836,
 2837,
 2838,
 2839,
 2840,
 2841,
 2842,
 2843,
 2844,
 2845,
 2846,
 2847,
 2848,
 2849,
 2850,
 2851,
 2852,
 2853,
 2854,
 2855,
 2856,
 2857,
 2858,
 2859,
 2860,
 2861,
 2862,
 2863,
 2864,
 2865,
 2866,
 2867,
 2868,
 2869,
 2870,
 2871,
 2872,
 2873,
 2874,
 2875,
 2876,
 2877,
 2878,
 2879,
 2880,
 2881,
 2882,
 2883,
 2884,
 2885,
 2886,
 2887,
 2888,
 2889,
 2890,
 2891,
 2892,
 2893,
 2894,
 2895,
 2896,
 2897,
 2898,
 2899,
 2900,
 2901,
 2902,
 2903,
 2904,
 2905,
 2906,
 2907,
 2908,
 2909,
 2910,
 2911,
 2912,
 2913,
 2914,
 2915,
 2916,
 2917,
 2918,
 2919,
 2920,
 2921,
 2922,
 2923,
 2924,
 2925,
 2926,
 2927,
 2928,
 2929,
 2930,
 2931,
 2932,
 2933,
 2934,
 2935,
 2936,
 2937,
 2938,
 2939,
 2940,
 2941,
 2942,
 2943,
 2944,
 2945,
 2946,
 2947,
 2948,
 2949,
 2950,
 2951,
 2952,
 2953,
 2954,
 2955,
 2956,
 2957,
 2958,
 2959,
 2960,
 2961,
 2962,
 2963,
 2964,
 2965,
 2966,
 2967,
 2968,
 2969,
 2970,
 2971,
 2972,
 2973,
 2974,
 2975,
 2976,
 2977,
 2978,
 2979,
 2980,
 2981,
 2982,
 2983,
 2984,
 2985,
 2986,
 2987,
 2988,
 2989,
 2990,
 2991,
 2992,
 2993,
 2994,
 2995,
 2996,
 2997,
 2998,
 2999,
 3000,
 3001,
 3002,
 3003,
 3004,
 3005,
 3006,
 3007,
 3008,
 3009,
 3010,
 3011,
 3012,
 3013,
 3014,
 3015,
 3016,
 3017,
 3018,
 3019,
 3020,
 3021,
 3022,
 3023,
 3024,
 3025,
 3026,
 3027,
 3028]
len(vertical_ref_series.index)

# %%
vertical_ref_series

# %%
data.loc[2104:,"vertical"]=vertical_ref_series

# %% [markdown]
# vertical column has been filled

# %%
data.iloc[2104::].head()

# %%
len(data[data["subvertical"].isna()]["startup"].to_list())

# %%
l=[
"Online Dating Platform",
"Live Video Streaming App",
"Mobile Advertising Platform",
"Enterprise Procurement Software",
"Personal Finance Management",
"Custom Furniture Marketplace",
"Genetic Testing Services",
"Social Media Management Tool",
"Food Delivery Marketplace",
"Online Grocery Delivery",
"Application Performance Monitoring",
"Customer Feedback Analytics",
"Subscription Billing Software",
"Daily Deals Marketplace",
"Language Localization Services",
"Mobile Game Development",
"Food Delivery Platform",
"Digital Payments Platform",
"Diabetes Diagnostic Solutions",
"Hyperlocal Delivery Service",
"Medical Learning Platform",
"Healthcare Analytics Platform",
"Travel Planning Platform",
"Digital Marketing Services",
"Rental Housing Platform",
"Digital Media Platform",
"Taxi Aggregator Service",
"Social Network for Golfers",
"Enterprise Cloud Solutions",
"Location Based Services",
"Logistics Delivery Service",
"Travel Community Platform",
"Digital Comics Studio",
"Assistive Technology Devices",
"Business Services Platform",
"File Sharing Platform",
"Used Car Marketplace",
"Marketing Analytics Platform",
"Payment Gateway Platform",
"Mobile POS Solutions",
"Furniture Rental Platform",
"Real Estate Investment Platform",
"Online Tea Marketplace",
"Lending Automation Software",
"Forex Exchange Platform",
"Job Marketplace Platform",
"Budget Hotel Aggregator",
"Short Video Social Platform",
"Media Streaming Device",
"HR Assessment Platform",
"Renewable Energy Solutions",
"EV Charging Solutions",
"Mobile App Development",
"Online Fashion Marketplace",
"Space Technology Startup",
"Microfinance Services",
"Payment Processing Platform",
"Trip Planning Platform",
"Cloud Networking Solutions",
"Mobile Insurance Services",
"Fashion E-commerce Platform",
"Email Marketing Platform",
"Health Food Products",
"Deals and Coupons Platform",
"Social Content Platform",
"Digital Wallet Platform",
"Mobile Wallet Services",
"Ready to Eat Food Delivery",
"SMB Digital Presence Platform",
"Baby Products E-commerce",
"Home Chef Food Delivery",
"Fresh Food Delivery",
"Retail Analytics Platform",
"Seafood Marketplace",
"Digital Content Studio",
"Digital Payments Platform",
"Premium Dating Platform",
"Digital Wallet Platform",
"News Aggregator App",
"Job Search Platform",
"Car Marketplace Platform",
"Cloud Kitchen Food Delivery",
"Automotive Marketplace",
"Rural E-commerce Platform",
"SME Lending Platform",
"Mobile Messaging Platform",
"Event Ticketing Platform",
"Local Search Platform",
"Homestay Booking Platform",
"Healthcare Appointment Platform",
"HR Compliance Software",
"Fashion Styling Platform",
"Digital Payment Solutions",
"News Aggregation App",
"Travel Booking Platform",
"IT Services Company",
"Social Commerce Platform",
"Creative Talent Marketplace",
"Video Sharing Platform",
"Visual Effects Studio",
"Developer Tools Platform",
"Home Interior Design Platform",
"Travel Deals Platform",
"Flight Booking Platform",
"Zero Brokerage Real Estate",
"Handicrafts Marketplace",
"Freelance Workforce Platform",
"Business Networking Platform",
"Tax Knowledge Platform",
"Online Grocery Delivery",
"Healthy Food Marketplace",
"B2B Industrial Marketplace",
"Grocery Delivery Platform",
"Food Delivery Platform",
"Mobile Payment App",
"Online Grocery Delivery",
"Eyewear E-commerce Platform",
"Fashion Social Platform",
"Hyperlocal Messaging Platform",
"Live Video Entertainment",
"Fitness Discovery Platform",
"Local Discovery Platform",
"Beauty Products E-commerce",
"Mobile Recharge Platform",
"Fraud Detection Platform",
"Messaging App Platform",
"Peer to Peer Lending",
"Parenting Products Marketplace",
"Fashion E-commerce Brand",
"Sports Analytics Wearables",
"Real Estate Platform",
"Digital Marketing Platform",
"Fashion E-commerce Brand",
"Food Ordering Platform",
"Wellness Products Marketplace",
"E-commerce Platform Builder",
"Growth Marketing Tools",
"Travel Analytics Platform",
"Crowdfunding Platform",
"Digital Healthcare Platform",
"Online Marketplace Platform",
"Referral Hiring Platform",
"Digital Marketing Agency",
"Health Products Marketplace",
"Hostel Booking Platform",
"Sports Booking Platform",
"Student Engagement Platform",
"Enterprise Productivity Platform",
"Media Broadcasting Network",
"Kids Fashion E-commerce",
"Ad Tech Platform",
"Health Products Marketplace",
"Online Education Platform",
"E-commerce Platform Builder",
"Social Networking App",
"Social Enterprise Incubator",
"Business Intelligence Platform",
"Organic Food Marketplace",
"English Learning Platform",
"AI Analytics Platform",
"Online Jewellery Marketplace",
"Job Recruitment Platform",
"Video Learning Platform",
"Social Networking App",
"Car Marketplace Platform",
"Rental Housing Platform",
"Online Printing Services",
"Material Technology Startup",
"AI Computer Vision",
"Hotel Marketing Software",
"Coupons Aggregation Platform"
]
print(len(l))

# %%
index_for_subvertical=data[data["subvertical"].isna()]["subvertical"].index.to_list()
index_for_subvertical
# indexes of missing values in subvertical column

# %%
ref_for_subvertical=pd.Series(l,index=index_for_subvertical)
ref_for_subvertical

# %%
# fill missing verticals in subvertical 
data.loc[2858::,"subvertical"]=ref_for_subvertical

# %%
data.iloc[2858::]

# %%
data[data["subvertical"].isna()]
# subvertical has been filled

# %%
data.to_csv('3files_cleaned.csv')

# %% [markdown]
# working  on city column (180 missing values)

# %%
data[data["city"].isna()]["startup"].to_list()

# %%
data["startup"].value_counts()

# %%
# code to see entire dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data[data["city"].isna()][['startup','vertical','investor']]

# %%
data["city"].fillna("unknown")

# %%
data[data["investor"].isna()]
# investor column has no missing values

# %%
data[data["amount"].isna()]
# amount column hs nomissing values

# %%
data["investor"]

# %%
data["round"]=data["round"].str.strip()

# %% [markdown]
# cleaning round column

# %%
data["round"].value_counts()

# %%
data["round"].unique()

# %%
# function to handle inconsistente values in round column
def handle_s_b (round):
    if round == 'SeriesB()':
        return "SeriesB"
    elif round == 'Private\\Equity':
        return 'PrivateEquity'
    elif round in ['Debt-Funding','DebtandPreferencecapital','StructuredDebt']:
        return 'DebtFunding'

    elif round in ['EquityBasedFunding','PrivateFunding','Private','Equity']:
        return 'PrivateEquity'
    elif round in ['SeriesC','SeriesD','SeriesF','SeriesE','SeriesG','SeriesH','SeriesJ']:
        return 'SeriesC+'
    elif round in ['Angel','AngelRound','Seedfunding','AngelFunding','SeedRound','SeedFunding','FundingRound','Seed/AngelFunding','Angel/SeedFunding','Seed\\Funding','SeedFundingRound','Seed/AngleFunding','Seed']:
        return "Seed/Angel"
    elif round in ["pre-seriesA",'Pre-seriesA','pre-SeriesA','PreSeriesA']:
        return 'Pre-SeriesA'
    else:
        return round

# %%
data["round"]=data["round"].apply(handle_s_b)

# %%
data["round"].value_counts()

# %%
df=pd.read_csv(r"C:\Users\Nadeem Anwar\Desktop\projects\startup dashboard\cleanedRoundColumn.csv")

# %%
data["round"]=df["round"]

# %%
data["round"]=data["round"].apply(lambda x :"others" if x in ['CorporateRound', 'VentureRound', 'MaidenRound', 'Venture',
       'SingleVenture', 'Venture-SeriesUnknown', 'BridgeRound',
       'InhouseFunding', 'Mezzanine', 'TermLoan', 'Crowdfunding',
       'CrowdFunding'] else x)

# %% [markdown]
# fixing starup column

# %%
data["startup"]=data["startup"].str.encode('utf-8').str.decode('unicode_escape').str.replace(r'\\xc2\\xa0', '', regex=True).str.replace(r'\\xe2\\x80\\x99', "'", regex=True).str.strip().str.encode('latin1', errors='ignore').str.decode('utf-8', errors='ignore').str.extract(r'^(?:https?:\/\/)?(?:www\.)?([^\.\/]+)')
# fixed startup column

# %%
data["startup"].unique()

# %% [markdown]
# fixing vertical column

# %%
data['vertical'].unique()

# %%
data['vertical'] = (
    data['vertical']
    .str.lower()
    .str.strip()
)

# %%
data["vertical"].value_counts()

# %%
standard_map = {
    # Fintech
    'fintech': 'fintech',
    'fin-tech': 'fintech',
    'financial tech': 'fintech',
    'fiinance': 'fintech',
    'finance':'fintech',
    'nbfc':'fintech',
    'bfsi':'fintech',
    'payments':'fintech', 
    'investment':'fintech',
    'insurance': 'fintech',
    'insurtech':'fintech',
    'trading':'fintech',
    'tax':'fintech',
    'crowdfunding':'fintechh',
    'fintechh':'fintech', 
    'accounting':'fintech',
    'compliance':'fintech', 
    'cashback':'fintech', 
    'rewards':'fintech', 
    'loyalty':'fintech',
    'fintechh':'fintech',

    # Ecommerce
    'ecommerce': 'ecommerce',
    'e-commerce': 'ecommerce',
    'e-commerce':'ecommerce',
    'e commerce': 'ecommerce',
    'ecommece': 'ecommerce',
    'online marketplace':"ecommerce" ,
    'marketplace':"ecommerce",
    'retail':"ecommerce",
    'consumer goods':'ecommerce',
    'fashion':'ecommerce',
    'fashion and apparel':'ecommerce',
    'grocery':'ecommerce',
    'beauty':'ecommerce',
    'furniture':"ecommerce",
    'jewelry':'ecommerce',
    'deals':'ecommerce',
    'coupons':'ecommerce',
    'consumer internet':'ecommerce',
    'ecommerceconsumer portal':'ecommerce',
    'consumer portal':'ecommerce',
    'saas, ecommerce':"ecommerce",
    
    

    # Edtec
    'edtech': 'edtech',
    'ed-tech': 'edtech',
    'education': 'edtech',
    'online education': 'edtech',
    'e-tech':'edtech',

    # Food
    'food': 'food',
    'food tech': 'food',
    'food and beverage': 'food',
    'foodtech':'food',
    'food & beverage':'food',
    'food & beverages':'food',
    'b2b-focused foodtech startup':'food',
    'food-tech':'food',
    'food and beverages':'food',
    'beverage':'food',
    'grocery':"food" ,
    'culinary':"food",
    'dairy':"food",
    'confectionery':"food",
    'agriculture':"food",
    'agtech':"food",
    'agritech':"food",
    
    


    # Health
    'healthcare': 'health',
    'health care': 'health',
    'healthtech': 'health',
    'health and wellness': 'health',


    # transportation_mobility
    'last mile transportation':'transport_mobility',
    'transport':'transport_mobility',
    'transportation':'transport_mobility',
    'logistics':'transport_mobility',
    'logistics tech':'transport_mobility',
    'mobility':'transport_mobility',
    'automotive':'transport_mobility',
    'automobile':'transport_mobility',
    'auto':'transport_mobility',
    'aviation':'transport_mobility',
    'ev':'transport_mobility',
    'travel':'transport_mobility',
    'travel tech':'transport_mobility', 
    'delivery':'transport_mobility',

    # tech
    'technology':'tech',
    'it':'tech',
    'information technology':'tech',
    'software': 'tech',
    'saas':'tech',
    'cloud':'tech',
    'ai':'tech',
    'artificial intelligence':'tech',
    'analytics':'tech', 
    'data':'tech' ,
    'automation':"tech",
    'robotics':'tech',
    'iot':'tech',
    'deep-tech':'tech' ,
    'hardware':'tech',
    'itservices':"tech", 
    'software':'tech',
    'ai':'tech', 
    'nanotechnology':'tech',
    'developer':'tech', 
    'cloud':'tech', 
    'security':'tech', 
    'telecom':'tech', 
    'infrastructure':'tech',
    'consumer technology':'tech',
    'wearables':'tech', 
    'govtech':'tech', 
    'aerospace':'tech',

    
    #enterprise_b2b
    'b2b':'enterprise_b2b',
    'b2b platform':'enterprise_b2b',
    'b2b marketing':'enterprise_b2b',
    'crm':"enterprise_b2b" ,
    'hr':"enterprise_b2b",
    'sales':"enterprise_b2b",
    'customer service':"enterprise_b2b",
    'customer service platform':"enterprise_b2b",
    'consulting':"enterprise_b2b",
    'saas':"enterprise_b2b", 
    'b2b':"enterprise_b2b", 
    'services':"enterprise_b2b", 
    'services platform':"enterprise_b2b", 
    'collaboration':"enterprise_b2b", 
    'hr':"enterprise_b2b", 
    'jobs':"enterprise_b2b", 
    'careers':"enterprise_b2b", 
    'survey':"enterprise_b2b", 
    'coworking':"enterprise_b2b",
    'freelance':"enterprise_b2b", 
    'talent':"enterprise_b2b", 
    'networking':"enterprise_b2b", 
    'reputation':"enterprise_b2b",




    #media and entertainment 
    'media':'media_entertainment',
    'digital media':'media_entertainment',
    'entertainment':'media_entertainment',
    'music':'media_entertainment',
    'gaming':'media_entertainment',
    'video':'media_entertainment',
    'video games':'media_entertainment',
    'publishing':'media_entertainment',
    'social media':'media_entertainment',
    'social':'media_entertainment',
    'social network':'media_entertainment', 
    'messaging':'media_entertainment', 
    'news':'media_entertainment', 
    'sports':'media_entertainment', 
    'media_entertainment':'media_entertainment', 
    'advertising':'media_entertainment', 
    'marketing':'media_entertainment', 
    'marketing':'media_entertainment',
    'events':'media_entertainment', 
    'adtech':'media_entertainment', 
    'storytelling':'media_entertainment', 
    'reality':'media_entertainment', 
    'art':'media_entertainment',
    'advertising, marketing':'media_entertainment',
    



    # health
    'fitness':"health",
    'mentalhealth':"health",
    'pharmacy':"health",
    'dental':"health",
    'wellness':"health",
    'pharma':'health', 


    #agriculture
    'agriculture':"agriculture",
    'agtech':"agriculture",
    'agritech':"agriculture",


    
    # climate tech
    "energy":"climte_tech",
    'clean-tech':"climate_tech",
    'sustainability':"climate_tech",
    'climte_tech':"climate_tech",
    'waste management service':"climate_tech", 
    'recycling':"climate_tech", 
    'water':"climate_tech",


    #lifestyle_consumer
    'lifestyle':"lifestyle_consumer",
    'home':"lifestyle_consumer",
    'interiors':"lifestyle_consumer",
    'design':"lifestyle_consumer",
    'wedding':"lifestyle_consumer",
    'dating':"lifestyle_consumer",
    'parenting':"lifestyle_consumer",
    'kids':"lifestyle_consumer",
    'gifting':"lifestyle_consumer",
    'community':"lifestyle_consumer",
    'consumer':'lifestyle_consumer',  
    'fmcg':'lifestyle_consumer', 
    'retail':'lifestyle_consumer', 
    'luxury':'lifestyle_consumer',
     'grooming':'lifestyle_consumer', 
     'babycare':'lifestyle_consumer', 
     'kitchen':'lifestyle_consumer', 
     'collectibles':'lifestyle_consumer', 
     'organic':'lifestyle_consumer', 
     'lingerie':'lifestyle_consumer',
     'luxury label':'lifestyle_consumer', 
     'consumer interne':'lifestyle_consumer',
     'consumer interne':'lifestyle_consumer',


     #realestate
     'real estate':'realestate',

       #others
     
    'hospitality':'others', 
    'inspiration':'others', 
    'local':'others', 
    'housing':'others',
    'nonprofit':'others', 
    'manufacturing':'others', 
    'storage':'others', 
    'printing':'others', 
    '3dprinting':'others',
    'industrial':'others', 
    'legal':'others', 
    'localization':'others', 
    'material':'others',

   


}

# %%
data["vertical"]=data["vertical"].replace(standard_map)

# %% [markdown]
# #it has appeared only one time so putting it in ecommerce

# %%
data["vertical"].unique()

# %%
data["vertical"].value_counts()

# %% [markdown]
# cleaned and standerdized vertical column

# %%
data.to_csv('cleaned_vertical.csv')

# %%
df=pd.read_csv('cleaned_vertical.csv')

# %%
df["city"].value_counts()

# %%
data["city"].value_counts()

# %% [markdown]
# ### Standardizing City Column
#
# The `city` column contains multiple inconsistencies such as:
# - Different spellings (e.g., "bangalore", "bengaluru", "bangaluru", "ahemadabad", "ahemdabad")
# - Mixed formats with multiple locations (e.g., "delhi/us", "bengaluru/boston")
# - Inconsistent casing and extra spaces
#
# **Steps taken:**
# - Converted all values to lowercase and removed extra spaces
# - Standardized common city name variations
# - Extracted the primary city when multiple locations were present (e.g., "delhi/us" → "delhi")
# - Replaced low-frequency cities (e.g., cities appearing very few times like "varanasi", "kanpur") with their respective states to reduce the number of categories
#
# This ensures consistent, clean, and more manageable city data for accurate analysis and visualization.

# %% [markdown]
# clean city column

# %%
#Convert values to lowercase and remove extra spaces for consistency.
data["city"]=(data["city"].str.lower().str.strip())

# %%
data["city"].value_counts().index

# %%
data["city"].value_counts()[data["city"].value_counts()<5].index# cities appeared less than 5 times

# %%
#number of time each city has appeared in city column
data["city"].value_counts()

# %% [markdown]
# ### Standardizing City Names Using Mapping
#
# The `city` column contained numerous inconsistent and non-standard entries, including:
# - Multiple city combinations (e.g., "bangalore / sfo", "new delhi / us")
# - Different spellings and naming variations (e.g., "bengaluru", "gurgaon", "ahemdabad")
# - International or irrelevant locations mixed with Indian cities (e.g., "india/us", "san francisco")
# - Localities instead of cities (e.g., "andheri", "haryana")
#
# **Approach:**
# - Created a custom mapping dictionary (`city_map`) to standardize values
# - Merged similar cities into a single canonical name (e.g., "bengaluru" → "bangalore", "gurgaon" → "delhi")
# - Extracted or prioritized primary Indian city where multiple locations were present
# - Replaced ambiguous or foreign-only entries with a common category ("others")
# - Mapped localities and regions to their respective major cities (e.g., "andheri" → "mumbai", "haryana" → "delhi")
#
# This approach ensures consistent city representation and reduces noise caused by fragmented or non-standard location data.

# %%
city_map={
    
    
    

    'noida / singapore':'delhi',
    'Bengaluru':'bangalore',
    'bengaluru':'bangalore',
    'gurugram':'delhi',
    'noida':'delhi',
    'gurgaon':'delhi',
    'bangalore / palo alto':'bangalore',
    'bangalore / sfo':'bangalore',
    
    'dallas / hyderabad':'hyderabad',
    'pune / us':'pune',
    'mumbai / global':'mumbai',
    'gurgaon / sfo':'delhi',
    'new delhi/ houston':'delhi',
    'bangalore / usa':'bangalore',
    'india / us':'others',
    'mumbai/bengaluru':'bangalore',
    'india/us':'others',
    'new delhi':'delhi',
    'pune / singapore':'pune',
    'mumbai / global':'mumbai',
    'chennai/ singapore':'chennai',
    'bangalore / san mateo':'bangalore',
    'new york/ india':'others',
    'san francisco ':'others',
    'bengaluru and gurugram':'delhi',
    'nw delhi':'delhi',
    'new delhi / us':'delhi',
    'mumbai / uk':'mumbai',
    'mumbai / ny':'mumbai',
    'hyderabad/usa':'hyderabad',
    'pune/seattle':'pune',
    'bangalore/ bangkok':'bangalore',
    'delhi & cambridge':'delhi',
    'seattle / bangalore':'bangalore',
    'new york, bengaluru':'bangalore',
     'goa/hyderabad':'hyderabad',
     'sfo / bangalore':'bangalore',
     'pune / dubai':'dubai',
     'haryana':'delhi',
     'ahmedabad':'ahemadabad',
     'new delhi / california':'delhi',
     'andheri':'mumbai',
     'ahemdabad':'ahemadabad',
     'kormangala': 'bangalore',
    'taramani': 'chennai',
    'chembur': 'mumbai',
    'kolkatta':'kolkata',
    'kormangala': 'bangalore',
    'chembur': 'mumbai',
    'taramani': 'chennai',
    'agra':'uttar pradesh',
    'lucknow':'uttar pradesh',
    'kanpur':'uttar pradesh',
    'nagpur':'mumbai',
    'faridabad':'delhi'
    
    
    
    
    
    
    
    
     


    


}

# %%
#Replaced inconsistent city values using a predefined mapping dictionary (`city_map`) to standardize entries.
data["city"]=data["city"].replace(city_map)

# %%
data['city']=data["city"].fillna('unknown')

# %%
# replacing foreign cities with foreign
foreign = [
    'san francisco', 'new york', 'london', 'boston',
    'california', 'palo alto', 'menlo park', 'santa monica',
    'burnsville', 'san jose,', 'missourie', 'dubai', 'singapore'
]

data['city'] = data['city'].replace(foreign, 'foreign')

# %% [markdown]
# replaces unclear cities and cities with less frequency <4(43) with others (us/india etc)

# %%
data["city"].value_counts()[data["city"].value_counts()<5].sum()

# %%
# citi names with less frequency and unclear cities
data["city"].value_counts()[data["city"].value_counts()<5].index

# %%
data["city"]=data["city"].apply(lambda city :'others' if city in ['others', 'bhopal', 'trivandrum', 'siliguri', 'surat', 'udaipur',
       'gwalior', 'udupi', 'kochi', 'india', 'tulangan', 'amritsar',
       'india/singapore', 'karnataka', 'bhubneswar', 'gaya', 'bhubaneswar',
       'rourkela', 'srinagar', 'karur', 'hubli', 'kerala', 'panaji',
       'kozhikode', 'us', 'usa', 'varanasi', 'jodhpur', 'usa/india', 'belgaum',
       'us/india'] else city)

# %%
data["city"].value_counts()

# %%
data.to_csv("cleaned_everything")

# %%
data[data["investor"].str.contains('/')]

# %%
data["investor"]=data["investor"].str.split(",")

# %%
data=data.explode("investor")

# %%
data.tail()

# %%
data["vertical"].value_counts()

# %%
# still to many vertical so changing agriculture to food,fintechh to fintech
map_dict={"fintechh":"fintech","agriculture":"food","climte_tech":"climate_tech"}

# %%
data["vertical"]=data["vertical"].replace(map_dict)

# %%
data["vertical"].value_counts()

# %%
data.to_csv("cleaned_everyting_latest")

# %%
data['vertical'] = data['vertical'].replace({
    'climate_tech': 'tech',
    'media_entertainment': 'tech',
    "fintech":"tech",
    "edtech":"tech",
    "enterprise_b2b":"tech"
})

# %%
data.to_csv("cleaned_everything_latest1")

# %%
data['vertical'].value_counts()

# %%
data.to_csv("cleaned_everything_latest1")

# %%
df_l1=pd.read_csv("cleaned_everything_exploded_latest1")

# %%
df["startup"].value_counts()

# %%
dfl=pd.read_csv("cleaned_everyting_exploded_latest")

# %%
dfl["startup"].value_counts()

# %%
c_s=pd.read_csv("cleaned_startups.csv")

# %%
# this df is not exploded, reducing number of verticals
c_s['vertical'] = c_s['vertical'].replace({
    'climate_tech': 'tech',
    'media_entertainment': 'tech',
    "fintech":"tech",
    "edtech":"tech",
    "enterprise_b2b":"tech",
    "climte_tech":"tech",
    "agriculture":"food",
    "fintechh":"tech"


    
})

# %%
c_s["vertical"].value_counts()

# %%
c_s.to_csv("cleaned_startups_unexploded.csv")

# %%
c_s["investor"]

# %% [markdown]
# # clean investors

# %%
c_s['investor']=c_s['investor'].str.replace("\\\\xe2\\\\x80\\\\x99","s")

# %%
c_s["investor"].iloc[108]

# %%
c_s["investor"]

# %%
c_s['investor'] = c_s['investor'].apply(
    lambda x: bytes(x, "utf-8").decode("unicode_escape") if isinstance(x, str) else x
)

# %%
c_s.to_csv("cleaned_startups_unexploded_latest")

# %%
test_df=pd.read_csv("cleaned_startups_unexploded_latest.csv")

# %% [markdown]
# 1.some startups are having no funds

# %%
test_df[test_df["startup"].str.contains("The Man Company",case=False)]

# %% [markdown]
# startups with no fundings

# %%
test_df[test_df["amount"]==0.0]

# %% [markdown]
# ### Data Cleaning amount column
#
# Funding values recorded as `0.0` were interpreted as undisclosed amounts rather than true zero funding.
# These were converted to `NaN` to prevent bias in aggregations such as mean and total funding, as pandas naturally excludes missing values in such computations.

# %%
test_df["amount"]=test_df["amount"].replace(0.0,np.nan)

# %%
test_df[test_df["amount"]==0.0]

# %%
test_df=pd.read_csv("cleaned_startups_unexploded_latest.csv")

# %%
test_df["startup"]=test_df["startup"].str.strip().str.lower().str.title()

# %%
test_df.to_csv("cleaned_startups_unexploded_latest.csv")

# %%
test_df["amount"]

# %%
test_df.head(1)

# %%
test_df=test_df.drop(columns=["Unnamed: 0.2","Unnamed: 0.1","Unnamed: 0"])

# %%
test_df[test_df["startup"]=='Byju’S']

# %%
test_df[test_df["startup"]=="Ola Cabs"]

# %% [markdown]
# ### Standardizing vertical and subvertical
#
# In this step, we clean and standardize the vertical and subvertical columns based on the startup name.
#
# Many entries in the dataset have inconsistent or missing categories. To fix this, we create a custom function that updates values for specific startups.
#
# **Approach**
#  * Check the startup name
#  * Assign correct vertical and subvertical
#  * Return the updated row

# %%
def make_consistent_vertical_subvertical (row):
    if row["startup"]=="Ola Cabs":
        row["vertical"]="transport_mobility"
        row["subvertical"]="Cab Booking app platform"

        return row

    elif row["startup"]=="Swiggy":
        row["vertical"]="Food Delivery"
        row["subvertical"]="Online Food Delivery"
        return row
    elif  row["startup"]== "Lenskart":
        row["subvertical"]="Online Eyewear Retailer"
        return row
    elif row["startup"]=="Paytm":
        row["vertical"]="FinTech"
        row["subvertical"]="Mobile Wallet"
        return row
    elif row["startup"]=="Urbanclap":
        row["vertical"]="Home Service"
        row["subvertical"]="Hyperlocal On-Demand Household Services platform"
        return row
    elif row["startup"]=="Lendingkart":
        row["vertical"]="FinTech"
        row["subvertical"]="Online Finance lending platform"
        return row
    elif row["startup"]=="Flipkart":
        row["subvertical"]="Online Marketplace"
        return row
    elif row["startup"]=="Medinfi":
        row["vertical"]="HealthTech"
        row["subvertical"]="Doctor & Clinic Discovery portal"
        return row
    elif row["startup"]=="Holachef":
        row["vertical"]="Food Delivery"
        row["subvertical"]="Online Food Delivery"
        return row
    
    elif row["startup"]=="Meesho":
        row["vertical"]="Ecommerce"
        row["subvertical"]="Online Marketplace For Resellers"
        return row 
    elif row["startup"]=="Nobroker":
        row["vertical"]="Real Estate"
        row["subvertical"]="Zero Brokerage Real Estate"
        return row
    elif row["startup"]=="Blackbuck":
        row["vertical"]="Logistics"
        row["subvertical"]="Largest Trucking Platform"
        return row
    elif row["startup"]=="Toppr":
        row["vertical"]="Edtech"
        row["subvertical"]="Online Education Platform"
        return row
    elif row["startup"]=="Nykaa":
        row["vertical"]="Ecommerce"
        row["subvertical"]="Beauty Products Etailers"
        return row
    elif row["startup"]=="Healthifyme":
        row["vertical"]="HealthTech"
        row["subvertical"]="Health & Fitness App"
        return row
    elif row["startup"]=="Cardekho":
        row["vertical"]="Auto-Tech"
        row["subvertical"]="Online Car Portal"
        return row
    elif row["startup"]=="Razorpay":
        row["vertical"]="FinTech"
        row["subvertical"]="Payment Gateway"
        return row
    elif row["startup"]=="Uniphore":
        row["vertical"]="Tech"
        row["subvertical"]="Speech Recognition"
        return row
    
    elif row["startup"]=="Grofers":
        row["vertical"]="Food"
        row["subvertical"]="Grocery Delivery"
        return row
    elif row["startup"]=="Aye Finance":
        row["vertical"]="FinTech"
        row["subvertical"]="Non-Banking Financial Company"
        return row
    elif row["startup"]=="Moglix":
        row["vertical"]="Ecommerce"
        row["subvertical"]="Industrial & Home products marketplace"
        return row
    elif row["startup"]=="Byju'S":
        row["vertical"]="EdTech"
        row["subvertical"]="Online Education Platform"
        return row
    elif row["startup"]=="Goqii":
        row["vertical"]="HealThtech"
        row["subvertical"]="Health & Fitness App"
        return row
    elif row["startup"]=='Wooplr':
        row["vertical"]="Ecommerce"
        row["subvertical"]="Women Fashion Portal"
        return row
    elif "Insurance" in  row["subvertical"] or "insurance" in row["subvertical"]:
        row["vertical"]="FinTech"
        row["subvertical"]="InsurTech"
        return row
    elif "Lending Platform" in row["subvertical"] or "Online lending" in row["subvertical"] or "Online Lending" in row["subvertical"] or "online lending platform" in row["subvertical"] :
        row["vertical"]="FinTech"
        row["subvertical"]="Online Lending Platform"
        return row
    elif  "Hotels" in row["subvertical"] or "hotels" in row["subvertical"] or "Hotel" in row["subvertical"] or "hotel" in row["subvertical"]:
        row["vertical"]="Travel & Hospitality"
        row["subvertical"]="Hotel Aggregator"
        return row
    else:
        return row
    
   

temp_df=test_df.apply(make_consistent_vertical_subvertical, axis=1)

# %%
temp_df[(temp_df["subvertical"].str.contains("Hotel")) | (temp_df["subvertical"].str.contains("hotels"))]

# %%
temp_df[temp_df["startup"]=="Healthians"]

# %%
temp_df[temp_df["subvertical"].apply(lambda x: "health" in x or "Health" in x)]["startup"].values

# %%
test_df["startup"].value_counts().iloc[25:30].reset_index()

# %%
test_df.to_csv("cleaned_startups_unexploded_latest_less_verticals.csv")

# %%
df=pd.read_csv("cleaned_startups_unexploded_latest_less_verticals.csv")

# %%
df[df["subvertical"].str.contains("Insurance")]
